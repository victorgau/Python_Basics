# %% [markdown]
# ## 讀取股價歷史資料
#
# 讀取股價歷史資料，並繪製線圖！
#
# 要使用 pandas data reader，記得要 pip install。
#
# ```bash
# c:\> pip install pandas-datareader
# ```

# %%
import pandas_datareader.data as web

# %%
df = web.DataReader("2330.tw", 'yahoo', "2018-01-01")
df[['Adj Close', 'Volume']].plot(subplots=True);
